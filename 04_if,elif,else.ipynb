# %% [markdown]
# <a href="https://colab.research.google.com/github/Krish-14190/Python-practice-code-with-solution/blob/main/if%2Celif%2Celse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1.Check whether a number is positive, negative, or zero.
number = int(input("Enter a number : "))
if number > 0:
  print(f"{number} is a positve number")
elif number == 0:
  print(f"{number} is zero")
else:
  print(f"{number} is a negative number")
# Out:
# Enter a number : 10
# 10 is a positve number

# %%
# 2.Check whether a number is even or odd.
number = int(input("Enter a number : "))
if number % 2 == 0:
  print(f"{number} is an even number")
else:
  print(f"{number} is an odd number")
# Out:
# Enter a number : 7
# 7 is an odd number

# %%
# 3.Find the greater of two numbers.
number1 = int(input("Enter a number : "))
number2 = int(input("Enter a number : "))
if number1>number2:
  print(f"{number1} is greater than {number2}")
elif number2>number1:
  print(f"{number2} is greater than {number1}")
else:
  print(f"Both numbers {number1} and {number2} are equal")
# Out:
# Enter a number : 10
# Enter a number : 10
# Both numbers 10 and 10 are equal

# %%
# 4.Find the largest of three numbers.
number1 = int(input("Enter a number : "))
number2 = int(input("Enter a number : "))
number3 = int(input("Enter a number : "))
if number1>=number2 and number1>=number3:
  print(f"{number1} is greater")
elif number2>=number1 and number2>=number3:
  print(f"{number2} is greater")
else:
  print(f"{number3} is greater")
# Out:
# Enter a number : 10
# Enter a number : 20
# Enter a number : 10
# 20 is greater

# %%
# 5.Check whether a person is eligible to vote (age ≥ 18).
age = int(input("Enter your age : "))
if age >=18 :
  print("You are eligible to vote ")
elif age<=0 :
  print("Please enter valid age")
else:
  print("You are not eligible to vote")
# Out:
# Enter your age : 0
# Please enter valid age

# %%
# 6.Check whether a year is a leap year.
year = int(input("Enter year :"))
if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
  print(f"{year} is a leap year")
else:
  print(f"{year} is not a leap year")
# Out:
# Enter year :1900
# 1900 is not a leap year

# %%
# 7.Check whether a number is divisible by 5.
number = int(input("Enter a number : "))
if number % 5 == 0 :
  print(f"{number} is divisible by 5")
else:
  print(f"{number} is not divisible by 5")
# Out:
# Enter a number : 0
# 0 is divisible by 5

# %%
# 8.Check whether a number is divisible by both 3 and 7.
number = int(input("Enter a number : "))
if number % 3 == 0 and number % 7 == 0 :
  print(f"{number} is divisible by both 3 and 7")
else:
  print(f"{number} is not divisible by both 3 and 7")
# Out:
# Enter a number : 30
# 30 is not divisible by both 3 and 7

# %%
# 9.Check whether a character is a vowel or consonant.
char = input("Enter a characetr : ")
if char.lower() in ['a','e','i','o','u']:
  print(f"{char} is a vowel")
else:
  print(f"{char} is consonant")
# Out:
# Enter a characetr : 5
# 5 is consonant

# %%
# 10.Check whether a character is uppercase or lowercase.
char = input("Enter a character : ")
if char.isupper():
  print(f"{char} is an uppercase character")
elif char.islower():
  print(f"{char} is a lowercase character")
else:
  print("Enter a valid character")
# Out:
# Enter a character : a
# a is a lowercase character

# %%
# 11.Calculate grade based on marks (A, B, C, D, F).
marks = int(input("Enter marks to check grade : "))
if marks>=90:
  print("Grade A")
elif 80<=marks<90:
  print("Grade B")
elif 60<=marks<80:
  print("Grade C")
elif 40<=marks<60:
  print("Grade D")
else:
  print("Grade F")
# Out:
# Enter marks to check grade : 59
# Grade D

# %%
# 12.Check whether a student passed or failed (passing marks = 35).
marks = int(input("Enter marks  : "))
if marks >=35 :
  print("Passed")
else:
  print("Failed")
# Out:
# Enter marks  : 33
# Failed

# %%
# 13.Check whether three sides can form a triangle.
'''formula :
a + b > c
a + c > b
b + c > a
that's how a traingle form'''
side_a = int(input("Enter side a : "))
side_b = int(input("Enter side b : "))
side_c = int(input("Enter side c : "))
if side_a <= 0 or side_b <= 0 or side_c <= 0:
    print("Please enter valid sides")
elif side_a + side_b > side_c and side_a + side_c > side_b and side_b + side_c > side_a:
  print("Can form a triangle")
else:
  print("Cannot form a triangle")
# Out:
# Enter side a : -1
# Enter side b : -3
# Enter side c : 5
# Please enter valid sides

# %%
# 14.Find the smallest of three numbers.
number_1 = int(input("Enter number : "))
number_2 = int(input("Enter number : "))
number_3 = int(input("Enter number : "))
if number_1<=number_2 and number_1<=number_3 :
  print(f"{number_1} is smallest")
elif number_2<=number_1 and number_2<=number_3:
  print(f"{number_2} is smallest")
else:
  print(f"{number_3} is smallest")
# Out:
# Enter number : 2
# Enter number : 1
# Enter number : 3
# 1 is smallest

# %%
# 15.Check whether a number is a multiple of both 2 and 5.

# %%
# 16.	Check whether a person is a child, teenager, adult, or senior citizen based on age.
age = int(input("Enter your age : "))
if age<0 :
  print("Age should not be negative")
elif age<=12:
  print("Child")
elif 13<=age<=19:
  print("Teenager")
elif 20<=age<=59:
  print("Adult")
else:
  print("Senior citizen")
# Out:
# Enter your age : 3
# Child

# %%
# 17.Create a simple calculator using +, -, *, /.
number_1 = int(input("Enter a number :"))
number_2 = int(input("Enter a number : "))
symbol = input("Enter + , - , * , / for calculation : ")
if symbol == '+':
  print(number_1 + number_2)
elif symbol == "-":
  print(number_1 - number_2)
elif symbol == "*":
  print(number_1 * number_2)
elif symbol == "/":
  if number_2 == 0 :
    print("Cannot divide by zero")
  else:
    print(number_1 / number_2)
else:
  print("Enter valid operator for calculation")
# Out:
# Enter a number :10
# Enter a number : 0
# Enter + , - , * , / for calculation : /
# Cannot divide by zero

# %%
# 18.Check whether a password entered matches the correct password.
password = "Krish141900"
user_password = input("Enter your password : ")
if user_password == password:
  print("Login")
else:
  print("Incorrect password")
# Out:
# Enter your password : Krish141900
# Login

# %%
# 19.Calculate discount based on purchase amount.
amount = int(input("Enter purchased amount : "))
if amount<0 :
  print("Enter valid amount")
elif amount >= 20000:
  print("30% discount")
elif amount >= 10000:
  print("25% discount")
elif amount >= 7000:
  print("20% discount")
elif amount >= 5000:
  print("10% discount")
else:
  print("No discount")
# Out:
# Enter purchased amount : 5500
# 10% discount

# %%
# 20.Check whether a person is eligible for a driving license.
age = int(input("Enter your age : "))
if age<0:
  print('Enter valid age')
elif age<18:
  print("Not eligible")
else:
  print("Eligible")
# Out:
# Enter your age : 21
# Eligible

# %%
# 21.Calculate income tax based on salary slabs.
salary = int(input("Enter salary : "))
if salary<0:
  print("enter valid salary")
elif salary<250000:
  print("0% tax")
elif 250000<=salary<=499999:
  print("10% tax")
elif 500000<=salary<=999999:
  print("20% tax")
else:
  print("30% tax")
# Out:
# Enter salary : 5
# 0% tax

# %%
# 22.Calculate electricity bill using different unit slabs
units = int(input("Enter units : "))
if units<0:
  print("Enter valid units")
elif 0<=units<=100:
  print("₹2 per unit")
elif 101<=units<=200:
  print("₹4 per unit")
elif 201<=units<=300:
  print("₹6 per unit")
else:
  print("₹8 per unit")
# Out:
# Enter units : 5
# ₹2 per unit
